# %% [markdown]
# ## AI TEXT SUMMARIZER

# %%
from openai import OpenAI
client = OpenAI(
    base_url="http://localhost:11434/v1",api_key="ollama")
print("AI Text Summarizer (type 'exit' to stop)\n")
while True:
    user = input("Enter your coding problem: ")

    if user.lower() == "exit":
        break
    response = client.chat.completions.create(
    model="llama3:8b",
    messages=[
        {"role": "system","content":
         "You are an AI TEXT summarizer . summarize the given text clearly and briefly."},
        {"role": "user",
         "content": user}])

    print("\nGenerated Code:\n")
    print(response.choices[0].message.content)
    print("\n" + "-"*60 + "\n")
# Out:
# AI Text Summarizer (type 'exit' to stop)
# Enter your coding problem:  Technology has become an important part of our daily life. People use smartphones, computers, and the internet for communication, education, and entertainment. Students use online platforms to learn new skills, while businesses use technology to improve their services and reach more customers. Although technology makes life easier and faster, it is also important to use it responsibly and avoid spending too much time on digital devices.
# Generated Code:
#
# Technology plays a significant role in daily life, facilitating communication, education, and entertainment. It helps students acquire new skills and businesses improve their services. While technology makes life easier and faster, it's essential to use it responsibly and strike a balance between technology use and other aspects of life.
#
# ------------------------------------------------------------
# Enter your coding problem:  exit
