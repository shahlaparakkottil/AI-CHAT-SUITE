# %% [markdown]
# ## AI EMAIL WRITER

# %%
from openai import OpenAI
client = OpenAI(
    base_url="http://localhost:11434/v1",api_key="ollama")
print(" AI EMAIL WRITER (type 'exit' to stop)\n")
while True:
    user = input("Enter your coding problem: ")

    if user.lower() == "exit":
        break
    response = client.chat.completions.create(
    model="llama3:8b",
    messages=[
        {"role": "system","content":
         "You are an  AI Email writer . give me a proffesional emails for the topics."},
        {"role": "user",
         "content": user}])

    print("\nGenerated Code:\n")
    print(response.choices[0].message.content)
    print("\n" + "-"*60 + "\n")
# Out:
#  AI EMAIL WRITER (type 'exit' to stop)
# Enter your coding problem:  iam sending reply for a job offer
# Generated Code:
#
# Here's a professional email template for responding to a job offer:
#
# Subject: Acceptance of Job Offer for [Job Title]
#
# Dear [Hiring Manager's Name],
#
# I am writing to formally accept the offer to join [Company Name] as [Job Title], as discussed during our interviews and outlined in your employment offer letter. I am thrilled to have been selected for this role and excited to contribute to the success of your team.
#
# Please confirm the terms of the offer, including the start date, salary, and any other key details. I am eager to begin work on [start date] and look forward to discussing the onboarding process further.
#
# Thank you for the opportunity to join [Company Name]. I am confident that my skills and experience will be a great fit for the team, and I am looking forward to working with you and the rest of the organization.
#
# Please do not hesitate to contact me if you require any additional information or clarification on any of the terms.
#
# Best regards,
#
# [Your Name]
#
# [Your Email Address]
#
# [Your Phone Number]
#
# Please note that you should customize this template to fit your specific situation and the details of the job offer. Also, make sure to proofread your email for grammar and spelling errors before sending it.
#
# ------------------------------------------------------------
# Enter your coding problem:  exit
